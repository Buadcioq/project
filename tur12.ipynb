# %%
import turtle
import random
t=turtle
t.up()
t.goto(0,30)
t.down
t.bgcolor('dodgerblue2')
t.shape('square')
t.color('green')
t.width(7)

# %% [markdown]
# Импортирование модулей Turtle и Random(Для разной скорости);Установка параметров первой черепашки(форма,ширина,цвет) и цвет фона холста;Перемещение первой черепашки в начальное положение.В последней заметке дан механизм работы кода целиком.

# %%
class Turtle():
    def turtle2_code():
        t2=turtle.Turtle()
        t2.up()
        t2.speed(1000)
        t2.goto(0,-30)
        t2.speed(1)
        t2.down()
        t2.shape('turtle')
        t2.color('purple')
        t2.width(5)
        def create_ellipse():
            turtle2_speed=random.randint(1,3)
            t2.fillcolor('brown')
            t2.begin_fill()
            t2.circle(75,45)
            t2.circle(45,90)
            t2.circle(75,90)
            t2.circle(45,90)
            t2.circle(75,45)
            t2.end_fill()
            t2.fillcolor('purple')
            t2.up()
            t2.goto(0,-30)
            t2.down()
        def create_triangle():
            turtle2_speed2=random.randint(4,6)
            t2.fillcolor('orange')
            t2.begin_fill()
            t2.left(45)
            t2.forward(100)
            t2.right(90)
            t2.forward(100)
            t2.right(135)
            t2.forward(140)
            t2.end_fill()
            t2.fillcolor('purple')
            t2.right(180)
            t2.up()
            t2.goto(0,-30)
            t2.down()
        while(True):
            g=input("Введите STOP,ellipse или triangle")
            if g=='STOP':
                t2.speed(1000)
                t2.up()
                t2.goto(-50,-50)
                t2.down()
                t2.write('I am turtle!')
                t2.up()
                t2.goto(0,-30)
                t2.down()
                t2.speed(1)
                break
            elif  g=='ellipse':
                t2.up()
                t2.goto(0,-30)
                t2.speed(1000)
                t2.goto(-200,-150)
                t2.speed(1)
                t2.down()
                create_ellipse()
                t2.up()
                t2.goto(0,-30)
                t2.down()
            elif g=='triangle':
                t2.up()
                t2.speed(1000)
                t2.goto(150,-150)
                t2.speed(1)
                t2.down()
                create_triangle()
                t2.up()
                t2.goto(0,-30)
                t2.down()
            else:
                None

# %% [markdown]
# Создание класса;Код второй черепашки:установка ее параметров(ширина,цвет,форма);Заготовка команд рисования фигур;Создание ввода с помощью бесконечного цикла While,его перезапуск при неправильном значении(Что угодно не являющееся:STOP,triangle и ellipse )его выходов(if,elif) с присоединенными командами рисовки фигур и установкой черепашки в начальное положение для рисовки фигуры.

# %%
def create_hexagon():
    turtle_speed=random.randint(1,3)
    t.speed(turtle_speed)
    t.fillcolor('red')
    t.begin_fill()
    t.left(135)
    t.forward(80)
    t.right(45)
    t.forward(80)
    t.right(45)
    t.forward(80)
    t.right(90)
    t.forward(80)
    t.right(45)
    t.forward(80)
    t.right(45)
    t.forward(80)
    t.left(135)
    t.end_fill()
    t.fillcolor('green')
    t.up()
    t.goto(0,30)
    t.down()
def create_rhombus():
    turtle_speed2=random.randint(4,6)
    t.speed(turtle_speed2)
    t.fillcolor('yellow')
    t.begin_fill()
    t.right(135)
    t.forward(130)
    t.right(45)
    t.forward(130)
    t.right(135)
    t.forward(130)
    t.right(45)
    t.forward(130)
    t.end_fill()
    t.fillcolor('green')
    t.up()
    t.goto(0,30)
    t.down()

# %% [markdown]
# Команда рисовки 'hexagon'-шестиугольника:Случайный выбор скорости,начало заливки,код рисовки фигуры,конец заливки

# %%
while(True):
    v=input("Введите STOP,hexagon или rhombus")
    if v=='STOP':
        t.speed(1000)
        t.up()
        t.goto(-50,50)
        t.down()
        t.write('Hello world!')
        t.up()
        t.goto(0,30)
        t.down()
        t.speed(1)
        Turtle.turtle2_code()
        break
    elif  v=='hexagon':
        t.up()
        t.speed(1000)
        t.goto(-200,120)
        t.speed(1)
        t.down()
        create_hexagon()
        t.up()
        t.goto(0,30)
        t.down()
    elif v=='rhombus':
        t.up()
        t.speed(1000)
        t.goto(240,240)
        t.speed(1)
        t.down()
        create_rhombus()
        t.up()
        t.goto(0,30)
        t.down()
    else:None

# %% [markdown]
# Код первой черепашки:С помощью бесконеченого цикла While создаем перезапуск строки ввода при неправильно введенном значении. С рисованием фигур при верно введенном значении с помощью команд If, elif.
# Работа кода:Программа создает первую черепашку с ее параметрами ( цвет, форма, след) и вместе с ней делает холст и его цвет. В бесконечный цикл while добавляем ввод, который перезапускается, если выполняется значение else ( что означает "если не выполнено все вышеперечисленное"). Когда программа получает значение STOP, то с помощью команды класса turtle, мы переходим на код второй черепашки.
# Во второй черепашки те же действия: ставим свою форму, цвет и размер сдела черепашки, измененяем координаты, фигуры, форму и цвет.
